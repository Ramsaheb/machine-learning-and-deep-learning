# %%
from matplotlib import pyplot
from tensorflow.keras.datasets import cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

print(x_train.shape, y_train.shape)
print('*****************************')
print(x_test.shape, y_test.shape)
for i in range(9):
    pyplot.subplot(330 + 1 + i)
    pyplot.imshow(x_train[i])
# Out:
# ...
# 170498071/170498071 [==============================] - 211s 1us/step
# (50000, 32, 32, 3) (50000, 1)
# *****************************
# (10000, 32, 32, 3) (10000, 1)

# %%
from tensorflow.keras.datasets import cifar100

(x_train, y_train), (x_test, y_test) = cifar100.load_data()
print(f"train_data_shape: {x_train.shape, y_train.shape}")
print(f"test_data_shape: {x_test.shape, y_test.shape}")

for i in range(9):
    pyplot.subplot(330 + 1 + i)
    pyplot.imshow(x_train[i])
# Out:
# ...
# 169001437/169001437 [==============================] - 273s 2us/step
# train_data_shape: ((50000, 32, 32, 3), (50000, 1))
# test_data_shape: ((10000, 32, 32, 3), (10000, 1))

# %%
from tensorflow.keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
print(f"train_data_shape: {x_train.shape, y_train.shape}")
print(f"test_data_shape: {x_test.shape, y_test.shape}")

for i in range(9):
    pyplot.subplot(330 + 1 + i)
    pyplot.imshow(x_train[i], cmap=pyplot.get_cmap('gray'))
# Out:
# train_data_shape: ((60000, 28, 28), (60000,))
# test_data_shape: ((10000, 28, 28), (10000,))

# %%
from tensorflow.keras.datasets import fashion_mnist

(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
print(f"train_data_shape: {x_train.shape, y_train.shape}")
print(f"test_data_shape: {x_test.shape, y_test.shape}")

for i in range(9):
    pyplot.subplot(330 + 1 + i)
    pyplot.imshow(x_train[i], cmap=pyplot.get_cmap('gray'))
# Out:
# ...
# 4422102/4422102 [==============================] - 1s 0us/step
# train_data_shape: ((60000, 28, 28), (60000,))
# test_data_shape: ((10000, 28, 28), (10000,))

# %%
from tensorflow.keras.datasets import imdb

(x_train, y_train), (x_test, y_test) = imdb.load_data(
    path='imdb.npz', num_words=None, skip_top=0, maxlen=None, seed=113, start_char=1,
    oov_char=2, index_from=3)
print(f"train_data_shape: {x_train.shape, y_train.shape}")
print(f"test_data_shape: {x_test.shape, y_test.shape}")
# Out:
# ...
# 17464789/17464789 [==============================] - 3s 0us/step
# train_data_shape: ((25000,), (25000,))
# test_data_shape: ((25000,), (25000,))

# %%
from tensorflow.keras.datasets import reuters
import numpy as np

(x_train, y_train), (x_test, y_test) = reuters.load_data(
    path='imdb.npz', num_words=None, skip_top=0, maxlen=None, seed=113, start_char=1,
    oov_char=2, index_from=3)
print(f"train_data_shape: {x_train.shape, y_train.shape}")
print(f"test_data_shape: {x_test.shape, y_test.shape}")
# Out:
# A local file was found, but it seems to be incomplete or outdated because the auto file hash does not match the original value of d6586e694ee56d7a4e65172e12b3e987c03096cb01eab99753921ef915959916 so we will re-download the data.
# ...
# 2110848/2110848 [==============================] - 1s 0us/step
# train_data_shape: ((8982,), (8982,))
# test_data_shape: ((2246,), (2246,))

# %%
from tensorflow.keras.datasets import boston_housing
import matplotlib.pyplot as plt
from scipy import stats as st

(x_train, y_train), (x_test, y_test) = boston_housing.load_data()
y = np.concatenate((y_train, y_test))

stats = st.describe(y)
print(stats)

print(f"train_data_shape: {x_train.shape, y_train.shape}")
print(f"test_data_shape: {x_test.shape, y_test.shape}")
# Out:
# DescribeResult(nobs=506, minmax=(5.0, 50.0), mean=22.53280632411067, variance=84.58672359409854, skewness=1.1048108228646372, kurtosis=1.4686287722747515)
# train_data_shape: ((404, 13), (404,))
# test_data_shape: ((102, 13), (102,))

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("yasserh/housing-prices-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████| 4.63k/4.63k [00:00<00:00, 4.53MB/s]
# Extracting files...
# Path to dataset files: C:\Users\Ramsaheb Prasad\.cache\kagglehub\datasets\yasserh\housing-prices-dataset\versions\1

# %%
import pandas as pd
df = pd.read_csv('housing.csv')

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
dataset = df.values
dataset
# Out:
# array([[13300000, 7420, 4, ..., 2, 'yes', 'furnished'],
#        [12250000, 8960, 4, ..., 3, 'no', 'furnished'],
#        [12250000, 9960, 3, ..., 2, 'yes', 'semi-furnished'],
#        ...,
#        [1750000, 3620, 2, ..., 0, 'no', 'unfurnished'],
#        [1750000, 2910, 3, ..., 0, 'no', 'furnished'],
#        [1750000, 3850, 3, ..., 0, 'no', 'unfurnished']], dtype=object)

# %%
X = dataset[:, [1, 2, 3, 4, 10]]
Y = dataset[:, 0]

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)
X_scale
# Out:
# array([[0.39656357, 0.6       , 0.33333333, 0.66666667, 0.66666667],
#        [0.5024055 , 0.6       , 1.        , 1.        , 1.        ],
#        [0.57113402, 0.4       , 0.33333333, 0.33333333, 0.66666667],
#        ...,
#        [0.13539519, 0.2       , 0.        , 0.        , 0.        ],
#        [0.08659794, 0.4       , 0.        , 0.        , 0.        ],
#        [0.15120275, 0.4       , 0.        , 0.33333333, 0.        ]])

# %%
from sklearn.model_selection import train_test_split

X_train, X_val_test, Y_train, Y_val_test = train_test_split(X_scale, Y, test_size=0.3)
X_val, X_test, Y_val, Y_test = train_test_split(X_val_test, Y_val_test, test_size=0.5)

print(X_train.shape, X_val.shape, X_test.shape, Y_train.shape)
