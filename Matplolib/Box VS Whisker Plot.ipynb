# %%
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4, 5, ]
x1 = [1, 3, 5, 6, 4]
y = [x, x1]

plt.boxplot(y, labels=['Python', 'Java'], notch=False, vert=True, widths=0.2, labels=['Pytho patch_artist=False,
            showmeans=True, boxprops={'color':'r'}, capprops={'color':'g'},
            whiskerprops={'color':'b'}, 
           )

plt.show()
