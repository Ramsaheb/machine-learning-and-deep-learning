# %%
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4, 5]
y = [2, 3, -4, 5, -6]

plt.stem(x, y, linefmt='|', markerfmt='ro', bottom=0.5, basefmt='g', label='Helloooo', ori)
plt.xlabel('range')
plt.ylabel('fluctuation')
plt.title('Stem', size=20)

plt.legend()
plt.show()
