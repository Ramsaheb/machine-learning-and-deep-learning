# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 3, 4, 5, 6])

plt.plot(x, y, color='r')
plt.fill_between(x, y,#x=[2, 4], y1=2, y2=4,
                 where=(x > 2) & (x < 4))

plt.show()
