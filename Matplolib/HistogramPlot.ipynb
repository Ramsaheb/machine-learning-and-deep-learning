# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
data = np.random.randint(10, 60, (50))
print(', '.join(map(str, data)))
# Out:
# 28, 36, 41, 56, 35, 16, 34, 52, 15, 17, 10, 10, 47, 17, 35, 12, 33, 43, 42, 14, 33, 40, 57, 41, 22, 48, 20, 36, 52, 34, 33, 30, 57, 33, 34, 39, 28, 24, 17, 22, 10, 14, 28, 53, 49, 58, 45, 32, 57, 12

# %%
x = [28, 36, 41, 56, 35, 16, 34, 52, 15, 17, 10, 10, 47, 17, 35, 12, 33,
     43, 42, 14, 33, 40, 57, 41, 22, 48, 20, 36, 52, 34, 33, 30, 57, 33,
     34, 39, 28, 24, 17, 22, 10, 14, 28, 53, 49, 58, 45, 32, 57, 12
]
l = [l for l in range(10, 61, 10)]
plt.hist(x, width=8, bins=l, histtype='barstacked',
         orientation='vertical', edgecolor='r', label='python')

plt.legend()
plt.show()

# %%
l = [l for l in range(10, 61, 10)]
l
# Out:
# [10, 20, 30, 40, 50, 60]
