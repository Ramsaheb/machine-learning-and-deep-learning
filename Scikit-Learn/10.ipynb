# %% [markdown]
# # Random Forest ALGO

# %%
import pandas as pd

# %%
df = pd.read_csv('car_evaluation/car.data')

# %%
df.head()
# Out:
#    vhigh vhigh.1  2 2.1  small   low  unacc
# 0  vhigh   vhigh  2   2  small   med  unacc
# 1  vhigh   vhigh  2   2  small  high  unacc
# 2  vhigh   vhigh  2   2    med   low  unacc
# 3  vhigh   vhigh  2   2    med   med  unacc
# 4  vhigh   vhigh  2   2    med  high  unacc

# %%
df.isnull().sum()
# Out:
# vhigh      0
# vhigh.1    0
# 2          0
# 2.1        0
# small      0
# low        0
# unacc      0
# dtype: int64

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
col_names = ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'class']

# %%
df.columns = col_names

# %%
df
# Out:
#      buying  maint  doors persons lug_boot safety  class
# 0     vhigh  vhigh      2       2    small    med  unacc
# 1     vhigh  vhigh      2       2    small   high  unacc
# 2     vhigh  vhigh      2       2      med    low  unacc
# 3     vhigh  vhigh      2       2      med    med  unacc
# 4     vhigh  vhigh      2       2      med   high  unacc
# ...     ...    ...    ...     ...      ...    ...    ...
# 1722    low    low  5more    more      med    med   good
# 1723    low    low  5more    more      med   high  vgood
# 1724    low    low  5more    more      big    low  unacc
# 1725    low    low  5more    more      big    med   good
# 1726    low    low  5more    more      big   high  vgood
#
# [1727 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1727 entries, 0 to 1726
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   buying    1727 non-null   object
#  1   maint     1727 non-null   object
#  2   doors     1727 non-null   object
#  3   persons   1727 non-null   object
#  4   lug_boot  1727 non-null   object
#  5   safety    1727 non-null   object
#  6   class     1727 non-null   object
# dtypes: object(7)
# memory usage: 94.6+ KB

# %%
 df.describe(include='all').T
# Out:
#          count unique    top  freq
# buying    1727      4   high   432
# maint     1727      4   high   432
# doors     1727      4      3   432
# persons   1727      3      4   576
# lug_boot  1727      3    med   576
# safety    1727      3    med   576
# class     1727      4  unacc  1209

# %%
for col in col_names:
    print(df[col].value_counts())
# Out:
# buying
# high     432
# med      432
# low      432
# vhigh    431
# Name: count, dtype: int64
# maint
# high     432
# med      432
# low      432
# vhigh    431
# Name: count, dtype: int64
# doors
# 3        432
# 4        432
# 5more    432
# 2        431
# Name: count, dtype: int64
# persons
# 4       576
# more    576
# 2       575
# Name: count, dtype: int64
# lug_boot
# med      576
# big      576
# small    575
# Name: count, dtype: int64
# safety
# med     576
# high    576
# low     575
# Name: count, dtype: int64
# class
# unacc    1209
# acc       384
# good       69
# vgood      65
# Name: count, dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [buying, maint, doors, persons, lug_boot, safety, class]
# Index: []

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe = OrdinalEncoder()

# %%
df['buying'] = oe.fit_transform(df[['buying']])
df['maint'] = oe.fit_transform(df[['maint']])
df['doors'] = oe.fit_transform(df[['doors']])
df['persons'] = oe.fit_transform(df[['persons']])
df['lug_boot'] = oe.fit_transform(df[['lug_boot']])
df['safety'] = oe.fit_transform(df[['safety']])
df['class'] = oe.fit_transform(df[['class']])

# %%
df
# Out:
#       buying  maint  doors  persons  lug_boot  safety  class
# 0        3.0    3.0    0.0      0.0       2.0     2.0    2.0
# 1        3.0    3.0    0.0      0.0       2.0     0.0    2.0
# 2        3.0    3.0    0.0      0.0       1.0     1.0    2.0
# 3        3.0    3.0    0.0      0.0       1.0     2.0    2.0
# 4        3.0    3.0    0.0      0.0       1.0     0.0    2.0
# ...      ...    ...    ...      ...       ...     ...    ...
# 1722     1.0    1.0    3.0      2.0       1.0     2.0    1.0
# 1723     1.0    1.0    3.0      2.0       1.0     0.0    3.0
# 1724     1.0    1.0    3.0      2.0       0.0     1.0    2.0
# 1725     1.0    1.0    3.0      2.0       0.0     2.0    1.0
# 1726     1.0    1.0    3.0      2.0       0.0     0.0    3.0
#
# [1727 rows x 7 columns]

# %%
X = df.iloc[:, 0: -1]
y = df.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.3)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
RFC = RandomForestClassifier()

# %%
RFC.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
pred1 = RFC.predict(X_test)

# %%
pred1
# Out:
# array([2., 2., 2., 0., 2., 0., 2., 2., 2., 2., 0., 2., 2., 2., 2., 2., 2.,
#        2., 2., 0., 2., 2., 0., 2., 2., 0., 2., 2., 2., 2., 0., 2., 2., 1.,
#        2., 2., 1., 2., 2., 3., 0., 0., 2., 2., 1., 0., 2., 2., 2., 2., 2.,
#        2., 0., 0., 2., 2., 2., 2., 2., 0., 2., 2., 2., 2., 2., 3., 2., 2.,
#        0., 2., 3., 0., 2., 2., 2., 0., 2., 2., 2., 2., 3., 2., 2., 0., 2.,
#        0., 2., 2., 0., 3., 2., 1., 2., 2., 2., 2., 2., 2., 2., 0., 2., 2.,
#        2., 2., 2., 1., 2., 2., 2., 0., 2., 0., 2., 2., 0., 2., 2., 2., 2.,
#        2., 2., 0., 2., 0., 0., 2., 0., 2., 2., 2., 2., 2., 2., 2., 2., 2.,
#        2., 2., 2., 2., 2., 0., 2., 0., 2., 0., 2., 2., 2., 2., 0., 3., 2.,
#        2., 2., 2., 2., 2., 2., 2., 0., 0., 2., 3., 2., 3., 0., 0., 2., 3.,
#        0., 2., 3., 2., 0., 0., 3., 2., 0., 2., 0., 2., 2., 0., 1., 2., 2.,
#        2., 2., 2., 2., 0., 0., 2., 2., 2., 0., 2., 2., 2., 2., 2., 2., 3.,
#        2., 0., 2., 0., 2., 3., 2., 2., 0., 2., 2., 2., 2., 2., 2., 0., 3.,
#        2., 2., 0., 3., 0., 0., 0., 2., 2., 0., 2., 2., 2., 0., 2., 0., 2.,
#        2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 0., 0.,
#        2., 2., 2., 2., 2., 0., 2., 3., 2., 2., 2., 0., 0., 2., 2., 2., 2.,
#        0., 2., 0., 0., 0., 1., 2., 2., 2., 1., 2., 0., 3., 0., 2., 1., 3.,
#        2., 1., 2., 2., 2., 0., 3., 2., 2., 2., 2., 0., 2., 2., 2., 2., 2.,
#        2., 2., 0., 2., 3., 2., 2., 2., 2., 0., 0., 0., 2., 2., 0., 2., 2.,
#        2., 2., 2., 1., 0., 2., 2., 2., 2., 2., 2., 2., 2., 2., 0., 2., 0.,
#        2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 0., 0., 2., 0., 2., 2.,
#        2., 3., 2., 2., 2., 0., 0., 0., 2., 3., 0., 2., 0., 2., 3., 2., 0.,
#        2., 2., 2., 0., 2., 0., 2., 2., 0., 2., 2., 2., 0., 2., 2., 2., 2.,
#        0., 0., 2., 2., 2., 2., 0., 0., 2., 2., 2., 2., 2., 2., 0., 2., 2.,
#        2., 2., 2., 2., 0., 0., 0., 0., 3., 0., 2., 2., 2., 0., 0., 2., 2.,
#        2., 2., 2., 0., 2., 0., 2., 2., 2., 0., 0., 2., 2., 2., 2., 2., 0.,
#        2., 2., 2., 2., 2., 2., 2., 0., 2., 3., 2., 2., 2., 2., 2., 0., 3.,
#        2., 2., 2., 2., 2., 2., 2., 2., 2., 0., 2., 2., 2., 2., 2., 2., 0.,
#        2., 2., 2., 2., 2., 2., 0., 2., 2., 0., 2., 2., 2., 2., 2., 2., 2.,
#        2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 0., 2., 0., 0., 2., 2.,
#        2., 2., 0., 2., 2., 2., 2., 2., 1.])

# %%
from sklearn.metrics import accuracy_score

# %%
print(accuracy_score(pred1, y_test))
# Out:
# 0.9653179190751445

# %%
from yellowbrick.model_selection import validation_curve

# %%
num_est = [100, 200, 450, 500, 750, 1000]
print(validation_curve(RandomForestClassifier(), X=X_train, y=y_train, param_name='n_estimators',
                       param_range=num_est, 
                       scoring='accuracy', cv=3))
# Out:
# ValidationCurve(ax=<Axes: title={'center': 'Validation Curve for RandomForestClassifier'}, xlabel='n_estimators', ylabel='score'>,
#                 cv=3, estimator=RandomForestClassifier(),
#                 param_name='n_estimators',
#                 param_range=array([ 100,  200,  450,  500,  750, 1000]),
#                 scoring='accuracy')

# %%
depth_val = [10, 7, 15, 12, 20, 22]
print(validation_curve(RandomForestClassifier(), X=X_train, y=y_train, param_name='max_depth',
                       param_range=depth_val, 
                       scoring='accuracy', cv=3))
# Out:
# ValidationCurve(ax=<Axes: title={'center': 'Validation Curve for RandomForestClassifier'}, xlabel='max_depth', ylabel='score'>,
#                 cv=3, estimator=RandomForestClassifier(),
#                 param_name='max_depth',
#                 param_range=array([10,  7, 15, 12, 20, 22]),
#                 scoring='accuracy')

# %%
min_samples = [3, 6, 4, 5, 8, 12, 15]
print(validation_curve(RandomForestClassifier(), X=X_train, y=y_train, param_name='min_samples_split',
                       param_range=min_samples, 
                       scoring='accuracy', cv=3))
# Out:
# ValidationCurve(ax=<Axes: title={'center': 'Validation Curve for RandomForestClassifier'}, xlabel='min_samples_split', ylabel='score'>,
#                 cv=3, estimator=RandomForestClassifier(),
#                 param_name='min_samples_split',
#                 param_range=array([ 3,  6,  4,  5,  8, 12, 15]),
#                 scoring='accuracy')

# %%
RFC2 = RandomForestClassifier(n_estimators = 1000, min_samples_split=3, max_depth=20, random_state=42)
RFC2.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=20, min_samples_split=3, n_estimators=1000,
#                        random_state=42)

# %%
pred2 = RFC2.predict(X_test)

# %%
pred2
# Out:
# array([2., 2., 2., 0., 2., 0., 2., 2., 2., 2., 0., 2., 2., 2., 2., 2., 2.,
#        2., 2., 0., 2., 2., 0., 2., 2., 0., 2., 2., 2., 2., 0., 2., 2., 1.,
#        2., 2., 1., 2., 2., 3., 0., 0., 2., 2., 1., 0., 2., 2., 2., 2., 2.,
#        2., 0., 0., 2., 2., 2., 2., 2., 0., 2., 2., 2., 2., 2., 3., 2., 2.,
#        0., 2., 3., 0., 2., 2., 2., 0., 2., 2., 2., 2., 3., 2., 2., 0., 2.,
#        0., 2., 2., 0., 0., 2., 1., 2., 2., 2., 2., 2., 2., 2., 0., 2., 2.,
#        2., 2., 2., 1., 2., 2., 2., 0., 2., 0., 2., 2., 0., 2., 2., 2., 2.,
#        2., 2., 0., 2., 0., 0., 2., 0., 2., 2., 2., 2., 2., 2., 2., 2., 2.,
#        2., 2., 2., 2., 2., 0., 2., 0., 2., 0., 2., 2., 2., 2., 0., 3., 2.,
#        2., 2., 2., 2., 2., 2., 2., 0., 0., 2., 3., 2., 3., 0., 0., 2., 3.,
#        0., 2., 3., 2., 0., 0., 3., 2., 0., 2., 0., 2., 2., 0., 1., 2., 2.,
#        2., 2., 2., 2., 0., 0., 2., 2., 2., 0., 2., 2., 2., 2., 2., 2., 3.,
#        2., 0., 2., 0., 2., 3., 2., 2., 2., 2., 2., 2., 2., 2., 2., 3., 3.,
#        2., 2., 0., 3., 0., 0., 0., 2., 2., 0., 2., 2., 2., 0., 2., 0., 2.,
#        2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 0., 0.,
#        2., 2., 2., 2., 2., 0., 2., 3., 2., 2., 2., 0., 0., 2., 2., 2., 2.,
#        0., 2., 0., 0., 0., 1., 2., 2., 2., 1., 2., 0., 3., 0., 2., 1., 3.,
#        2., 1., 2., 2., 2., 0., 3., 2., 2., 2., 2., 0., 2., 2., 2., 2., 2.,
#        2., 2., 0., 2., 3., 2., 2., 2., 2., 0., 0., 0., 2., 2., 2., 2., 2.,
#        2., 2., 2., 1., 0., 2., 2., 2., 2., 2., 2., 2., 2., 2., 0., 2., 0.,
#        2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 0., 0., 2., 0., 2., 2.,
#        2., 3., 2., 2., 2., 0., 0., 0., 2., 3., 0., 2., 0., 2., 3., 2., 3.,
#        2., 2., 2., 0., 2., 0., 0., 2., 0., 2., 2., 2., 0., 2., 2., 2., 2.,
#        0., 0., 2., 2., 2., 2., 0., 0., 2., 2., 2., 2., 2., 2., 0., 2., 2.,
#        2., 2., 2., 2., 0., 0., 0., 0., 3., 0., 2., 2., 2., 0., 0., 2., 2.,
#        2., 2., 2., 0., 2., 0., 2., 2., 2., 0., 0., 2., 2., 2., 2., 2., 0.,
#        2., 2., 2., 2., 2., 2., 2., 0., 2., 3., 2., 2., 2., 2., 2., 0., 3.,
#        2., 2., 2., 2., 2., 2., 2., 2., 2., 0., 2., 2., 2., 2., 2., 2., 0.,
#        2., 2., 2., 2., 2., 2., 0., 2., 2., 0., 2., 2., 2., 2., 2., 2., 2.,
#        2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 0., 2., 0., 2., 2., 2.,
#        2., 2., 0., 2., 2., 2., 2., 2., 1.])

# %%
print(accuracy_score(pred2, y_test))
# Out:
# 0.9633911368015414

# %%
feature_scores = pd.Series(RFC2.feature_importances_, index=X_train.columns).sort_values(ascending=False)
print(feature_scores)
# Out:
# safety      0.279566
# persons     0.229201
# buying      0.185016
# maint       0.156538
# lug_boot    0.083287
# doors       0.066392
# dtype: float64

# %%
sns.barplot(x=feature_scores, y=feature_scores.index)
plt.show()

# %%
RFC3 = RandomForestClassifier()

# %%
Xn = df.drop(['doors', 'lug_boot', 'maint'], axis=1)

# %%
yn = df['class']

# %%
X_trainn, X_testn, y_testn, y_trainn = train_test_split(Xn, yn, test_size=0.2)

# %%
RFC3.fit(X_trainn, y_trainn)
new_pred = RFC3.predict(X_testn)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 RFC3.fit(X_trainn, y_trainn)
#       2 new_pred  =RFC3.predict(X_testn)
#
# File ~\.conda\envs\Itachi\lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\.conda\envs\Itachi\lib\site-packages\sklearn\ensemble\_forest.py:363, in BaseForest.fit(self, X, y, sample_weight)
#     360 if issparse(y):
#     361     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 363 X, y = self._validate_data(
#     364     X,
#     365     y,
#     366     multi_output=True,
#     367     accept_sparse="csc",
#     368     dtype=DTYPE,
#     369     force_all_finite=False,
#     370 )
#     371 # _compute_missing_values_in_feature_mask checks if X has missing values and
#     372 # will raise an error if the underlying tree base estimator can't handle missing
#     373 # values. Only the criterion is required to determine if the tree supports
#     374 # missing values.
#     375 estimator = type(self.estimator)(criterion=self.criterion)
#
# File ~\.conda\envs\Itachi\lib\site-packages\sklearn\base.py:650, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     648         y = check_array(y, input_name="y", **check_y_params)
#     649     else:
# --> 650         X, y = check_X_y(X, y, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\.conda\envs\Itachi\lib\site-packages\sklearn\utils\validation.py:1291, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1273 X = check_array(
#    1274     X,
#    1275     accept_sparse=accept_sparse,
#    (...)
#    1286     input_name="X",
#    1287 )
#    1289 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
# -> 1291 check_consistent_length(X, y)
#    1293 return X, y
#
# File ~\.conda\envs\Itachi\lib\site-packages\sklearn\utils\validation.py:460, in check_consistent_length(*arrays)
#     458 uniques = np.unique(lengths)
#     459 if len(uniques) > 1:
# --> 460     raise ValueError(
#     461         "Found input variables with inconsistent numbers of samples: %r"
#     462         % [int(l) for l in lengths]
#     463     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [1381, 346]
