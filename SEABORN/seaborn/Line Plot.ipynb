# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
var1 = [1, 2, 3, 4, 5]
var2 = [2, 3, 4, 5, 6]

#data = pd.DataFrame({'var1':var1, 'var2':var2})

#sns.lineplot(x='var1', y='var2', data=data)
sns.lineplot(x=var1, y=var2)

plt.show()

# %%
data = sns.load_dataset('anagrams')
data
# Out:
#     subidr    attnr  num1  num2  num3
# 0        1  divided     2   4.0     7
# 1        2  divided     3   4.0     5
# 2        3  divided     3   5.0     6
# 3        4  divided     5   7.0     5
# 4        5  divided     4   5.0     8
# 5        6  divided     5   5.0     6
# 6        7  divided     5   4.5     6
# 7        8  divided     5   7.0     8
# 8        9  divided     2   3.0     7
# 9       10  divided     6   5.0     6
# 10      11  focused     6   5.0     6
# 11      12  focused     8   9.0     8
# 12      13  focused     6   5.0     9
# 13      14  focused     8   8.0     7
# 14      15  focused     8   8.0     7
# 15      16  focused     6   8.0     7
# 16      17  focused     7   7.0     6
# 17      18  focused     7   8.0     6
# 18      19  focused     5   6.0     6
# 19      20  focused     6   6.0     5

# %%
sns.lineplot(x='subidr', y='attnr', data=data, hue='num3', size=40, style='num3', palette='Accent', markers=['o', '*'], dashes=)
plt.show()
# Out:
# C:\Windows\Temp\ipykernel_7268\3814819043.py:1: UserWarning:
# The markers list has fewer values (2) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(x='subidr', y='attnr', data=data, hue='num3', size=40, style='num3', palette='Accent', markers=['o', '*'])
