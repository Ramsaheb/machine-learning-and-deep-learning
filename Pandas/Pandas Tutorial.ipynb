# %% [markdown]
# # welcome to pandas tutorial

# %%
import numpy as np
import pandas as pd

# %%
dict1 = {"name":["ram", "kunal", "salman"],
         "marks":[87, 98, 78],
         "city":["palghar", "palghar", "bhivandi"]
        }

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#      name  marks      city
# 0     ram     87   palghar
# 1   kunal     98   palghar
# 2  salman     78  bhivandi

# %%
df.to_csv('frineds.csv', index = False)  #exel sheet

# %%
df.head(2)
# Out:
#     name  marks     city
# 0    ram     87  palghar
# 1  kunal     98  palghar

# %%
df.tail(2)
# Out:
#      name  marks      city
# 1   kunal     98   palghar
# 2  salman     78  bhivandi

# %%
df.describe()
# Out:
#            marks
# count   3.000000
# mean   87.666667
# std    10.016653
# min    78.000000
# 25%    82.500000
# 50%    87.000000
# 75%    92.500000
# max    98.000000

# %%
ramsaheb = pd.read_csv('ram.csv')

# %%
ramsaheb
# Out:
#   player_name  score      city
# 0         ram     87   palghar
# 1       kunal     98   palghar
# 2      salman     78  bhivandi

# %%
ramsaheb['score']
# Out:
# 0    87
# 1    98
# 2    78
# Name: score, dtype: int64

# %%
ramsaheb['score'][0] = 100
# Out:
# C:\Windows\Temp\ipykernel_15092\3506014547.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ramsaheb['score'][0] = 100

# %%
ramsaheb
# Out:
#   player_name  score      city
# 0         ram    100   palghar
# 1       kunal     98   palghar
# 2      salman     78  bhivandi

# %%
ramsaheb.to_csv('ramsaheb.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 ramsaheb.to_csv('ramsaheb.csv')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:3772, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3761 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3763 formatter = DataFrameFormatter(
#    3764     frame=df,
#    3765     header=header,
#    (...)
#    3769     decimal=decimal,
#    3770 )
# -> 3772 return DataFrameRenderer(formatter).to_csv(
#    3773     path_or_buf,
#    3774     lineterminator=lineterminator,
#    3775     sep=sep,
#    3776     encoding=encoding,
#    3777     errors=errors,
# ...

# %%
ramsaheb.index = ['first', 'second', 'third']

# %%
ramsaheb
# Out:
#        player_name  score      city
# first          ram    100   palghar
# second       kunal     98   palghar
# third       salman     78  bhivandi

# %%
ser = pd.Series(np.random.rand(35))

# %%
ser
# Out:
# 0     0.646829
# 1     0.102303
# 2     0.457240
# 3     0.774097
# 4     0.520539
# 5     0.677728
# 6     0.202407
# 7     0.410937
# 8     0.576389
# 9     0.808228
# 10    0.693898
# 11    0.343317
# 12    0.393034
# 13    0.860152
# 14    0.449368
# 15    0.266558
# 16    0.899234
# 17    0.613757
# 18    0.416983
# 19    0.410805
# 20    0.194380
# 21    0.751308
# 22    0.957315
# 23    0.953991
# 24    0.008597
# 25    0.705869
# 26    0.108172
# 27    0.459764
# 28    0.133601
# 29    0.202500
# 30    0.407196
# 31    0.505142
# 32    0.560044
# 33    0.372201
# 34    0.893938
# dtype: float64

# %%
newdf = pd.DataFrame(np.random.rand(334, 5), index = np.arange(334))

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.437478  0.193325  0.603032  0.824011  0.784722
# 1    0.850252  0.279342  0.840852  0.630993  0.003517
# 2    0.017601  0.681625  0.205804  0.297733  0.967657
# 3    0.187273  0.737192  0.928424  0.410636  0.518003
# 4    0.468247  0.720969  0.721151  0.094870  0.206271
# ..        ...       ...       ...       ...       ...
# 329  0.281147  0.493535  0.667316  0.950206  0.189643
# 330  0.682571  0.366301  0.829889  0.597888  0.490849
# 331  0.307919  0.409829  0.832690  0.213887  0.865065
# 332  0.720845  0.917256  0.786488  0.823979  0.534009
# 333  0.310992  0.161502  0.819824  0.503212  0.298023
#
# [334 rows x 5 columns]

# %%
newdf.head(5)
# Out:
#           0         1         2         3         4
# 0  0.437478  0.193325  0.603032  0.824011  0.784722
# 1  0.850252  0.279342  0.840852  0.630993  0.003517
# 2  0.017601  0.681625  0.205804  0.297733  0.967657
# 3  0.187273  0.737192  0.928424  0.410636  0.518003
# 4  0.468247  0.720969  0.721151  0.094870  0.206271

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0
# %%
newdf
# Out:
#               0         1         2         3         4
# 0    513.000000  0.193325  0.603032  0.824011  0.784722
# 1      0.850252  0.279342  0.840852  0.630993  0.003517
# 2      0.017601  0.681625  0.205804  0.297733  0.967657
# 3      0.187273  0.737192  0.928424  0.410636  0.518003
# 4      0.468247  0.720969  0.721151  0.094870  0.206271
# ..          ...       ...       ...       ...       ...
# 329    0.281147  0.493535  0.667316  0.950206  0.189643
# 330    0.682571  0.366301  0.829889  0.597888  0.490849
# 331    0.307919  0.409829  0.832690  0.213887  0.865065
# 332    0.720845  0.917256  0.786488  0.823979  0.534009
# 333    0.310992  0.161502  0.819824  0.503212  0.298023
#
# [334 rows x 5 columns]

# %%
newdf2
# Out:
#                0         1         2         3         4
# 0    6541.000000  0.193325  0.603032  0.824011  0.784722
# 1       0.850252  0.279342  0.840852  0.630993  0.003517
# 2       0.017601  0.681625  0.205804  0.297733  0.967657
# 3       0.187273  0.737192  0.928424  0.410636  0.518003
# 4       0.468247  0.720969  0.721151  0.094870  0.206271
# ..           ...       ...       ...       ...       ...
# 329     0.281147  0.493535  0.667316  0.950206  0.189643
# 330     0.682571  0.366301  0.829889  0.597888  0.490849
# 331     0.307919  0.409829  0.832690  0.213887  0.865065
# 332     0.720845  0.917256  0.786488  0.823979  0.534009
# 333     0.310992  0.161502  0.819824  0.503212  0.298023
#
# [334 rows x 5 columns]

# %%
newdf.loc[0, 0] = 5364

# %%
newdf.head(2)
# Out:
#              0         1         2         3         4
# 0  5364.000000  0.193325  0.603032  0.824011  0.784722
# 1     0.850252  0.279342  0.840852  0.630993  0.003517

# %%
newdf.columns = list("ABCDE")

# %%
newdf.head(2)
# Out:
#              A         B         C         D         E
# 0  5364.000000  0.193325  0.603032  0.824011  0.784722
# 1     0.850252  0.279342  0.840852  0.630993  0.003517

# %%
newdf.loc[0, 'A'] = 5364

# %%
newdf
# Out:
#                A         B         C         D         E
# 0    5364.000000  0.193325  0.603032  0.824011  0.784722
# 1       0.850252  0.279342  0.840852  0.630993  0.003517
# 2       0.017601  0.681625  0.205804  0.297733  0.967657
# 3       0.187273  0.737192  0.928424  0.410636  0.518003
# 4       0.468247  0.720969  0.721151  0.094870  0.206271
# ..           ...       ...       ...       ...       ...
# 329     0.281147  0.493535  0.667316  0.950206  0.189643
# 330     0.682571  0.366301  0.829889  0.597888  0.490849
# 331     0.307919  0.409829  0.832690  0.213887  0.865065
# 332     0.720845  0.917256  0.786488  0.823979  0.534009
# 333     0.310992  0.161502  0.819824  0.503212  0.298023
#
# [334 rows x 5 columns]

# %%
newdf.drop('A', axis = 1)
# Out:
#             B         C         D         E
# 0    0.193325  0.603032  0.824011  0.784722
# 1    0.279342  0.840852  0.630993  0.003517
# 2    0.681625  0.205804  0.297733  0.967657
# 3    0.737192  0.928424  0.410636  0.518003
# 4    0.720969  0.721151  0.094870  0.206271
# ..        ...       ...       ...       ...
# 329  0.493535  0.667316  0.950206  0.189643
# 330  0.366301  0.829889  0.597888  0.490849
# 331  0.409829  0.832690  0.213887  0.865065
# 332  0.917256  0.786488  0.823979  0.534009
# 333  0.161502  0.819824  0.503212  0.298023
#
# [334 rows x 4 columns]

# %%
newdf.loc[[1, 2], :]
# Out:
#           A         B         C         D         E
# 1  0.850252  0.279342  0.840852  0.630993  0.003517
# 2  0.017601  0.681625  0.205804  0.297733  0.967657

# %%
newdf.loc[: , ['B', 'C']]
# Out:
#             B         C
# 0    0.193325  0.603032
# 1    0.279342  0.840852
# 2    0.681625  0.205804
# 3    0.737192  0.928424
# 4    0.720969  0.721151
# ..        ...       ...
# 329  0.493535  0.667316
# 330  0.366301  0.829889
# 331  0.409829  0.832690
# 332  0.917256  0.786488
# 333  0.161502  0.819824
#
# [334 rows x 2 columns]

# %%
newdf
# Out:
#                A         B         C         D         E
# 0    5364.000000  0.193325  0.603032  0.824011  0.784722
# 1       0.850252  0.279342  0.840852  0.630993  0.003517
# 2       0.017601  0.681625  0.205804  0.297733  0.967657
# 3       0.187273  0.737192  0.928424  0.410636  0.518003
# 4       0.468247  0.720969  0.721151  0.094870  0.206271
# ..           ...       ...       ...       ...       ...
# 329     0.281147  0.493535  0.667316  0.950206  0.189643
# 330     0.682571  0.366301  0.829889  0.597888  0.490849
# 331     0.307919  0.409829  0.832690  0.213887  0.865065
# 332     0.720845  0.917256  0.786488  0.823979  0.534009
# 333     0.310992  0.161502  0.819824  0.503212  0.298023
#
# [334 rows x 5 columns]

# %%
newdf.loc[(newdf['B'] < 0.3) & (newdf['c'] > 0.1)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'c'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
newdf.head(2)
# Out:
#              A         B         C         D         E
# 0  5364.000000  0.193325  0.603032  0.824011  0.784722
# 1     0.850252  0.279342  0.840852  0.630993  0.003517

# %%
newdf.iloc[0, 4]
# Out:
# 0.7847222470087639

# %%
newdf.drop([0], inplace = True)

# %%
newdf
# Out:
#             A         B         C         D         E
# 1    0.850252  0.279342  0.840852  0.630993  0.003517
# 2    0.017601  0.681625  0.205804  0.297733  0.967657
# 3    0.187273  0.737192  0.928424  0.410636  0.518003
# 4    0.468247  0.720969  0.721151  0.094870  0.206271
# 5    0.074967  0.918771  0.469828  0.890222  0.477104
# ..        ...       ...       ...       ...       ...
# 329  0.281147  0.493535  0.667316  0.950206  0.189643
# 330  0.682571  0.366301  0.829889  0.597888  0.490849
# 331  0.307919  0.409829  0.832690  0.213887  0.865065
# 332  0.720845  0.917256  0.786488  0.823979  0.534009
# 333  0.310992  0.161502  0.819824  0.503212  0.298023
#
# [333 rows x 5 columns]

# %%
newdf['A'].isnull()
# Out:
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 329    False
# 330    False
# 331    False
# 332    False
# 333    False
# Name: A, Length: 333, dtype: bool

# %%
newdf.loc[: , ['B']] = 'ram'

# %%
newdf['B'].isnull()
# Out:
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 329    False
# 330    False
# 331    False
# 332    False
# 333    False
# Name: B, Length: 333, dtype: bool

# %% [markdown]
# **Exercize**

# %%
df1 = pd.DataFrame(np.random.rand(3, 3), index = np.arange(3))

# %%
df1
# Out:
#           0         1         2
# 0  0.091641  0.680186  0.307468
# 1  0.339254  0.668601  0.942051
# 2  0.230530  0.140645  0.729036

# %%
df1.describe()
# Out:
#               0         1         2
# count  3.000000  3.000000  3.000000
# mean   0.220475  0.496477  0.659518
# std    0.124113  0.308214  0.322952
# min    0.091641  0.140645  0.307468
# 25%    0.161085  0.404623  0.518252
# 50%    0.230530  0.668601  0.729036
# 75%    0.284892  0.674393  0.835543
# max    0.339254  0.680186  0.942051

# %%
df1.mean()
# Out:
# 0    0.220475
# 1    0.496477
# 2    0.659518
# dtype: float64

# %%
df1.corr()
# Out:
#           0         1         2
# 0  1.000000 -0.088895  0.993129
# 1 -0.088895  1.000000 -0.204848
# 2  0.993129 -0.204848  1.000000

# %%
df1.count()
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
df1.max()
# Out:
# 0    0.339254
# 1    0.680186
# 2    0.942051
# dtype: float64

# %%
df1.min()
# Out:
# 0    0.091641
# 1    0.140645
# 2    0.307468
# dtype: float64

# %%
df1.median()
# Out:
# 0    0.230530
# 1    0.668601
# 2    0.729036
# dtype: float64
